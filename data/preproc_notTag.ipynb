# %%
#-*- coding:utf-8 -*-
import re #정규 표현식 모듈

# %%
fp=open('7CM00044.txt', 'r', encoding='utf-16')
ff=open('chat.log','w',encoding='utf-8')

# %%
Nstr = re.compile("\/[\W].*?")

isText = 0; 
cnt =0;

while True:
    line = fp.readline()
    
    #대화 문장만 추출 해 냄
    if not line:
        break
    elif (line == "<text>\n"):
        isText = 1
    elif (line == "</text>\n"):
        isText = 0

    if (isText != 1):
        continue
        
    #
    person = re.search('<u who="P\d">',line, re.I|re.S)
    if (person is not None):
        print (line[8:10]+ ": ", end='')
        
    personEnd = re.search('</u>',line, re.I|re.S)
    line = re.sub('<.*?>','',line ,0, re.I|re.S)
    line = re.sub(',','',line ,0, re.I|re.S)
    line = re.sub('\n','',line ,0, re.I|re.S)
    line = re.sub('::','',line ,0, re.I|re.S)
    line = re.sub('<trunc>.*</trunc>','',line ,0, re.I|re.S)
    
    #한 사람이 말 한 내용이 없으면(한숨 같은 효과음) 없애기
    #line = re.sub('  ',' ',line ,0, re.I|re.S)
        
    " ".join(line.split())
    

    if (personEnd is not None): #한사람 말 끝나면 줄넘김
        print(line)
        ff.write(line+"\n")
        cnt=cnt+1
    else: #말 이어서 하는중이면 줄넘김 없음
        print(line, end='')
        print(" ", end='')
        ff.write(line)
        
    if cnt == 2:
        print("")
        cnt = 0

fp.close()
ff.close()
# Out:
#  P1: 아 이제 돼.
# P2: 아 되는 거야 인제?
#
# P1: 예. 인제 여기다가 말씀하시면 돼요.
# P2: 복잡하네.
#
# P1:  어 그리고 오늘 여기 여기 사람 없어 가지구
# P2: 응.
#
# P1: 녹음 잘 될 것 같은데.  원래 사람 있으면 시끄러워서 잘 안 돼요.
# P2: 노랫소리.
#
# P1: 노랫소리는 뭐~  아 이 정도는 뭐~ 괜찮아요. 오빠 회사는 다니실만 하세요?
# P2: 그렇지 뭐~
#
# P1: 그래도 잘 다니셔야죠
# P2: 그래야지 어떻게 들어간 회산데. 에휴 이번에 취업문 더 좁아진대더라. 신문 보니까?
#
# P1: 맞아요.
# P2: 나라가 어떻게 될라는지.
#
# P1: 오빤 거기서 뭐하세요?
# P2: 나?
#
# P1: 네.
# P2: 나 뭐~ 그거 하지. 뭐~ 설계
#
# P1: 설계요?
# P2: 응.
#
# P1: 뭐~ 자동 자동차 설계 이런 거요?
# P2: 그니까. 차 만들 때?
#
# P1: 네.
# P2: 야 참 여러 파트가 있잖냐.
#
# P1: 네.
# P2: 보통 이만 개 부품이 들어가는데?
#
# P1: 네.
# P2: 고급차는 삼만 개까지 들어가
#
# P1: 네. 부품이요?
# P2: 어. 부품이. 부품이 여러 개다 보니깐. 뭉뚱그려서 그냥 개별적인 그른 게 아니구.
#
# P1: 네.
# P2: 단위별로 있다고. 예를 들어서 엔진에 들어가는
#
# P1: 네.
# P2: 엔진에 들어가는 그런 부품도 있고
#
# P1: 네.
# P2: 고 담에 인제 뭐~ 휠에 뭐~ 서스펜선이라고 인제 충격완화장치 있잖아.
#
# P1: 네.
# P2: 지혜 자동차 좋아하나?
#
# P1: 저요?
# P2: 어.
#
# P1: 이쁜 차는 좋아해요.
# P2: 아 비틀 같은 거?
#
# P1: 네.
# P2: 아
#
# P1: 좋지 잘 만들었지 그것두
# P1: 아 뭐지? 오빠 거기 홈페이지에 보니까. 차 이런 거 되게 많던데요?
#
# P2: 아 그거?
# P1: 네.
#
# P2: 얼마 전부터 인제 아는 중심으로 인제 사진과 함께 설명을 해 줄라구
# P1: 네.
#
# P2: 아는 거 중심으로 해 가주구. 만들었는데. 모르겠다.
# P1: 그~ 현대 차 있던데? 현대. 쏘나타.
#
# P2: 아 엔에프?
# P1: 아 그게 원래 그냥 뭐~ 뭐지? 프로젝트 명이 엔에프가 아니라 확실한 이름이 엔에프예요?
#
# P2: 그럴 거야 아마. 엔에프 쏘나타. 아 이에프도 이에프 쏘나타잖아.
# P1: 예.
#
# P2:  그 이에프가. 엘레 엘레전트 후론티어. 쏘나타란 뜻이야.  엘레전트.
# P1: 아 그럼 엔에프는요?
#
# P2: 엔에프는 뭐 뉴 제너레이션
# P1:
#
# P2: 뭐~ 프론티어. 아무튼. 사활을 걸고 만든 거 같애.
# P1: 음
#
# P2: 분수령이 될 거야 아마.
# P1: 음. 근데 이쁘던데.
#
# P2: 차가 아우디  미안.
# P1:
#
# P2: 차가 아우디를 본떠서 만든 거거든? 아우디.
# P1: 음. 들어 본 거 같애요.
#
# P2: 응 옆모습이. 아우디랑 정말 닮았어.
# P1: 음
#
# P2: 오늘 오늘 스포티지 신문 광고 봤는데.
# P1: 스포티지요?
#
# P2: 어.
# P1: 왜요 왜?
#
# P2:  기아에서 신차 나온 거 거든? 그게?
# P1: 예.
#
# P2: 그것도 되게 이뻐. 보면 알지만. 차가 좀 남자 중심인데?
# P1: 음
#
# P2: 투산하고 투산의 좀 이케 그런 거 하고.
# P1: 아 오빠 이제 돼요. 이거. 뭐지? 밧떼리가 없어서 잘 안됐어요.
#
# P2: 아 그래?
# P1: 네. 어디까지 이야기했죠?
#
# P2: 아 기아에서 신차 나왔다고.
# P1: 아. 스포티지?
#
# P2: 응. 스포티지. 뉴 스포티지.
# P1:
#
# P2: 차 많이 잘 팔릴 거야.
# P1: 오빠는? 디자인 같은 건 안 해요? 아 그건 디자이너들이 하는구나?  끄쵸?
#
# P2: 디자이너들이 하는 것도 있구
# P1: 네.
#
# P2: 디자이너들이 인제 엔지니어들한테 건네 줘.
# P1: 네.
#
# P2: 그 디자인 도안을
# P1: 네.
#
# P2: 그러면 인제 디자이너들은 이쁘게만 만들려고 한단 말이야.
# P1: 네.
#
# P2: 창의적으로. 그런데 엔지니어들은 인제 여러 가지 인제 제약이 많으니까.
# P1: 네.
#
# P2: 그거를 막 다 카트 시키지.
# P1:  응
#
# P2: 그래서 인제 디자이너들하구. 엔지니어들하구 맨날 싸운대
# P1: 아
#
# P2: 근데 디자이너들하구 엔지니어하구 이렇게 중간 다리 역할하는. 엔지니어가 또 있어.
# P1: 네.
#
# P2: 거 뭐~ 별로 없지 근데 그건.
# P1: 그런 사람이 별로 없다구요?
#
# P2: 어. 그 외는 많이 필요가 없을 것 아니야.
# P1: 왜요?
#
# P2: 그건 잘 모르겠다.
# P1:  요샌 그럼 뭐 하고 지내세요?
#
# P2: 나?
# P1: 네.
#
# P2: 회사 다니지.
# P1:
#
# P2: 지혜는 점점 예뻐지네.
# P1: 저요?
#
# P2: 음.
# P1: 별말씀을요.
#
# P2: 별말씀이지 그지?
# P1:
#
# P2: 홈피 놀러 와서. 글도 남기고 그래
# P1: 어 하나 남겼어요 어제.
#
# P2: 응
# P1: 어제 못 보셨네 못 봤네요?
#
# P2: 아 오늘 가서 봐야 봐야겠네? 그럼.
# P1: 네.
#
# P2: 어디다오디다 썼는데. 게시판?
# P1: 아뇨  방명록.
#
# P2: 사진첩? 방명록?
# P1: 네.
#
# P2: 지혜 남자 친구 있어?
# P1: 있죠
#
# P2: 아 그래 니가 없으면 말이 안 되지.
# P1:
#
# P2: 남자 친구 몇 살인데?
# P1: 한 살 한 살 많아요.
#
# P2: 한 살?
# P1: 네.
#
# P2: 뭐~ 꽈는 뭐야?
# P1: 기계공학과요.
#
# P2: 학교는?
# P1: 연세대학교요.
#
# P2: 아 몇 학년이야 그러면? 군대 갔다 왔어?
# P1: 아 갔다 왔죠 어 저랑 한 학기 차이 나요. 인제 육학기.
#
# P2:  너는 칠학기구?
# P1: 전 칠학기.
#
# P2: 남자 친구가 한참 바쁠 때네?
# P1: 네.
#
# P2: 니가 고생시키면 안 되겠다 야.
# P1: 제가 고생 안 시켜요.
#
# P2: 공대 육학기면은 진짜 눈코 뜰 새 없이 바쁘지.
# P1: 아니 뭐가 바빠요? 공대는 왜 바빠요?
#
# P2: 공대?
# P1: 네.
#
# P2: 학기 중에는 진짜. 오빠가 또 공대 나왔지 않냐.
# P1: 네.
#
# P2: 오빠도 기계과 나왔는데.
# P1: 네.
#
# P2: 뭐라 그래야 돼나. 일단 뭐~ 공부하는 거 자체가 인제 쫌 어렵고. 할 게 많아 할 게
# P1: 그래요?
#
# P2: 숙제라든지 뭐~ 이런 거 하나 하나가. 뭐~ 또 시험도 많이 보고. 워낙? 많은 지식을 배우니까.  그만큼 또.
# P1: 공대가 내용이 내용이 어려워서 어려워 힘든 건가?
#
# P2: 그릏지
# P1: 어차피 수업 시간은 다 똑같을 거 아니에요? 그쵸?
#
# P2: 그치. 심팔 학점 뭐~ 들으면은
# P1: 근데 수업이. 내용이 어려워서 힘든가?
#
# P2: 내용도 어렵고.
# P1: 응.
#
# P2: 완전 한 번. 흐름 놓치면 끝나지
# P1: 응
#
# P2: 다시 독 독학을 하면은. 진짜 힘들어 그게.  그래서
# P1: 독학하기가요?
#
# P2: 어 어. 그래서 교수들도 뭐~ 다 안 가르쳐 주구. 필요한 것만 가르치잖아.
# P1: 왜요?
#
# P2: 워낙 많으니까 분량두
# P1: 음.
#
# P2: 다 가르쳐 줄 필요도 없고. 워낙 또. 요즘에 공대가. 공학 같은 경우에는. 과학이니까
# P1: 네.
#
# P2: 빨리 빨리 업데이트가 되잖아
# P1: 예.
#
# P2: 근까 뭐~ 죽은 기술 가르쳐 줘 봤자잖아.
# P1: 응
#
# P2: 그런 게 또 있지. 기본적인 건 다 많이 배워 두는 게 좋아. 남자 친구가 공분 잘 하나?
# P1: 아 잘 한 거 잘 해요.
#
# P2: 잘 해?
# P1: 네.
#
# P2:  취직 잘 되겠네.
# P1: 예 왜 학점이 좋아야 취직이 잘 돼요?
#
# P2: 공대에서 학점. 따기 힘들거든. 성실하지 않으면.
# P1: 근데 어 어저께두 학교 오빠를 만났는데 그 오빠두 그러던데요? 요새는 토익이 점수가 다 똑같대요
#
# P2: 응.
# P1: 다들 잘 보니깐.
#
# P2: 응.
# P1: 그래서. 학 학 학점 중요하다고. 학점 잘 따놓으라고 이러던데.
#
# P2: 그치. 토익 같은 거는 뭐~ 뭐~ 문 문과 쪽이면. 구백오십 뭐~.
# P1:  구백오십이요?
#
# P2: 지혜는 몇 점 나오는데?
# P1:  열심히 할려구요
#
# P2: 말투가 상당히 귀엽네. 남자친구한테도 이런 말투 써?
# P1:
#
# P2: 뭐~ 뭐~ 했구요 했구요
# P1:
#
# P2: 본인은 못 느끼지? 말투가 아주 귀여워 귀염직스럽네.
# P1:
#
# P2: 그래? 남자 친구는
# P1:  학점이 네.
#
# P2: 남자 친구는 뭐~ 어디 가고 싶어한대?
# P1: 남자 친구요?
#
# P2:  취직 취직 취직할 거래. 대학원 갈 거래.
# P1: 아 잘 몰르겠어요. 생각 중인가 봐요.
#
# P2: 음. 기계과면은 자동차 회사 많이 오는데.
# P1: 자동차요?
#
# P2: 응.
# P1: 아
#
# P2: 기계과는 어디 가나 다 뭐라고 그래야 되나. 쓸모가 있으니까
# P1: 응.
#
# P2: 활용도가 커 그래서. 여러 가지 분야에서 많이 뽑아.
# P1: 아 기계과를요?
#
# P2: 상대적으로 근데 쪼끔 인제. 뭐라 그래야 되나. 전기 전자 부문보다는.
# P1: 예.
#
# P2: 약간 쫌 빡센. 그런 업종에 가지. 빡세다는 건. 중공업이라든지.
# P1: 아.
#
# P2: 말만 들어도 쫌 이제
# P1: 아 그~ 그럼 그 그건 어디로 가요? 금속공학과는?
#
# P2: 잘 가면은 인제 포철이나. 포철 아이엔아이스틸.
# P1: 아.
#
# P2: 포스코 포스코.
# P1: 그런데 가서 뭐 하는 거예요? 뭘 하지? 금속공학과.
#
# P2: 금속공학과두? 자동차 회사 많이 가구.
# P1: 아 하긴 그러겠네요
#
# P2: 금속공학과가 상대적으로 전기나 뭐~ 기계공학 이런 거보다는 적어.
# P1: 사람이요?
#
# P2: 응. 근데 금속도 괜찮지
# P1: 음
#
# P2: 신소재. 이쪽으로 가면은.
# P1: 음.
#
# P2: 공대가 취직은 잘 되지.
# P1: 그래요?
#
# P2: 지만 열심히 하면은.
# P1: 취직이 어디예요. 취직이
#
# P2: 그러게. 지혜는 어디 가고 싶은데?
# P1: 저요?
#
# P2: 응.
# P1: 은행이요.
#
# P2: 수협?
# P1: 농협.
#
# P2: 수협은 어때?
# P1: 수협이요? 수협?  몰르겠어요. 근데 저희 사 사촌 사촌 오빠가 아니라. 학교 오빠는요 어제께도 얘기했는데. 그 오빠가 삼성 다니거든요?
#
# P2: 응.
# P1: 얘기하다가
#
# P2: 뭐~ 삼성생명?
# P1: 삼성화재요.
#
# P2: 아 삼성화재?
# P1: 근데. 어제 그러던데요. 그냥 일단 삼성은 넣어너 보라고 그르든데요? 삼성이 첫 회사 되면 좋으니깐. 근데 이 오빠는 삼성이 좋긴 한데? 자기는 농협이 더 좋대요.
#
# P2: 음 선배들이 다. 취직 많이 했나?
# P1: 아니요? 둘이요.
#
# P2: 하나는 삼성 다니는 선배랑
# P1: 한 명은 대우증권이요
#
# P2: 증권?
# P1: 네.
#
# P2: 증권맨이네
# P1:
#
# P2: 증권이 활황일 때는. 진 증권맨들이 돈 진짜 많이 벌어.
# P1: 아
#
# P2: 뭐~ 수당가치 이런 게 떨어지거든. 수수료 같은 게?
# P1: 아
#
# P2: 근데 예를 들어서
# P1: 어 아니 아 그러더라고요. 아 어저께 얘길 하는데? 주가가? 아 주간가 뭔지가 잘 모르겠는데 아무튼 천 포인튼가 넘으면은? 연봉이 일억이래요. 이천 포인트가 넘으면은? 이억.
#
# P2: 근까 왜 그러냐면? 거래량 위주로.
# P1: 응.
#
# P2: 인제 수당이 떨어지거든?
# P1: 예.
#
# P2: 주가가? 바닥이어두? 거래량만 많아두 거래량만 많으면? 상관이 없어.
# P1:  아.
#
# P2: 요즘 같으면은 거래두 뭐~. 대형 우량주밖에 거래가 안 되고. 증시를 사람들이 안 한단 말이야. 워낙 불안하니깐.
# P1: 맞아요.
#
# P2: 그래 가지구. 증권맨들이 뭐~ 칠십만 원 벌어간다는데 한 달에
# P1: 칠십만 원이요?  그거밖에 안 되면.
#
# P2: 그렇게 힘들더라고.
# P1: 어
#
# P2: 블황일 때는. 증시가 직격탄을 맞으니까.
# P1: 아
#
# P2: 증권맨들은 아주 죽을 맛이구. 호황일 때는 저기 여의도 증권가 난리 나잖아.
# P1: 그쵸.
#
# P2: 룸싸롱 맨날 꽉꽉 차고 막.
# P1:
#
# P2: 진짜루 거기서 막 돈 푸는 거야.
# P1: 그렇구나.
#
# P2: 그래서 니 선배라는. 그 형도?
# P1: 네.
#
# P2: 아마 지금 고민이 좀 많을 거다.
# P1: 왜요?
#
# P2: 아무래도 지금 꼐속 불황의 조짐이 보이니까
# P1:  쫌 있다가 그~ 뭐지? 유학 갈려고 그러는 거 같던데요?
#
# P2: 유학?
# P1: 네. 왜냐면 거기서만 있을 거 같진 않아요. 유학 가서. 뭐를 해야지 뭐~ 좀 높은 직급으로. 된대요. 요새는. 그래서 아마 유학 갈 거 같애요. 몇 년 후에. 엠비에이 이런 데를 갈려고 해두 실무 경력이 오 년인가 삼 년 이상은 돼야 되거든요?
#
# P2: 요즘에는 오 년.
# P1: 요새 오 년?
#
# P2: 응.
# P1: 그래서 아 그러면 한 오 년 있다 가겠네
#
# P2: 옛날에 삼 년이었는데. 저기 아이비리그 있잖아
# P1: 예.
#
# P2: 십 대 엠비에이.
# P1: 네.
#
# P2: 그랬는데 오 년으로 늘렸대. 불황이어서.
# P1: 네
#
# P2: 그 쪽에서두 불황이니까
# P1: 네.
#
# P2: 유학생들 많이 받겠나?  워낙 취업 안 돼서 다시 대학원 쪽으로 공부하러 오는 사람 많아 가지구.  아는 형이?
# P1: 네.
#
# P2: 저기 현대증권 다니다가
# P1: 네.
#
# P2: 엠비에이 준비하다가.
# P1: 네.
#
# P2: 안 돼 가지구.
# P1: 네.
#
# P2: 그냥 한국에 있는 회사 다녀.
# P1: 아
#
# P2: 안 된대 잘 거기는.
# P1: 응
#
# P2:   아 이게 지금 십 분 녹취했다는 거야?
# P1: 네. 근데 아까 한 삼 분 하고 빳데리 없어서. 끊겼을걸요? 아 지금 한 십삼 분 정도?
#
# P2: 아  이게 소니 거네?
# P1: 네. 그거 막 만지면 안돼요
#
# P2: 아. 아니야
# P1: 아니네?  그런 건 뭐예요? 처음 봤다 다.
#
# P2: 아 이 위에 걸 누르면은.
# P1: 네
#
# P2: 타임이 나와. 십삼 분 했다는 소리고.
# P1: 아
#
# P2: 지금 현재 이번 타임에 한 거는? 남은 건 이만큼 남았다는 거고?
# P1: 아 리메인 아.
#
# P2: 줄어들지? 그 다음에 요거는 이번 타임에 한 거. 이렇게 하는 게 낫겠지. 그지?
# P1:  지금? 아 우와! 네. 오!  오 몰랐네요.
#
# P2: 벽돌 같다 야.
# P1: 되게 크죠?
#
# P2: XX 갖고 다니기 힘들겠다.
# P1: 이제 좀 익숙해요.
#
#
# P2: 아르바이트야?
#
# P1: 아니 사촌 언니가 연구하는 거예요. 연구.  연구하는 거예요.
# P2: 아. 비가 이렇게 오냐.  저녁은 먹었어?
#
# P1: 저녁이요? 네. 오빠 영화 많이 보세요?
# P2: 영화?
#
# P1: 네.
# P2: 많이 봐지.
#
# P1: 오빠두? 아 오빠는 주말에는 가세요 회사?
# P2: 아니 우리 주오일이야.
#
# P1: 그럼 주말엔 뭐 하세요?
# P2: 주말에 놀아.
#
# P1:  뭐 하고요?
# P2: 아 오빠 저기 뭐냐 농구 동호회하거든. 동호회?
#
# P1: 음
# P2: 아 그래서. 그 사람들하고. 주말을 거의 같이 보내지.
#
# P1:  아. 농구만 하고요?
# P2: 응. 뭐~ 애인이 없으니까 뭐~.
#
# P1: 음. 왜 오빠 여자 친구 없어요
# P2: 아. 글쎄? 안 생기네. 지혜가 하나 소개 시켜 줄라나?
#
# P1:  회사에는 괜찮은 사람 없어요?
# P2: 다 남자거든.
#
# P1:  아
# P2: 아무래두 회사가 회사다 보니.
#
# P1: 예.
# P2: 여자들이. 거의 없지 전무하지 전무. 있는 부서도 있어.
#
# P1: 아 음 그러믄 그러믄 그러면 선 같은 보세요 선? 듀오 듀온가? 듀온가 선운가?
# P2:  야 그것두. 그것두 가입비 같은 것도 만만치 않고. 귀찮더대라구 해 본 사람 주변에 몇 있거든?
#
# P1: 네.
# P2: 차라리 그냥 뭐~ 학교 후배한테 뭐~ 소개 받아서 이런 게 낫지?
#
# P1: 오빠가 너무 눈이 높으신 거 아니에요?
# P2: 나?
#
# P1: 네.
# P2: 글쎄 나는 그냥
#
# P1: 오빠도 막~ 전지현. 막 이런 애들이 이쁘죠?
# P2: 아냐 아냐 아냐. 나는. 어~ 참한 애가 좋아.
#
# P1: 참한 애?
# P2: 응.
#
# P1: 음. 그런 애 많잖아요. 잘 찾아보세요
# P2: 시간이 있어야지.
#
# P1: 아
# P2: 남자 친구 잘 사겨
#
# P1: 네.
# P2: 뭐~ 겨우 십육 분 했다고?
#
# P1:
# P2: 오빠랑 있는 게 지루하니?
#
# P1: 아니요
# P2: 왜 자꾸 시간을 봐.
#
# P1: 아니 녹음이 잘 되나 본 거예요.
# P2: 음. 남자 친구랑도 하지 왜?
#
# P1: 남자 친구랑도 했어요. 몇 번 해 가지구
# P2: 응.
#
# P1: 한 두 번 두세 번 했나?
# P2: 응.
#
# P1: 그래서. 너무 많이 하면은 안 되니까
# P2: 음.
#
# P1: 그랬죠
# P2:  핸드폰 이쁘다
#
# P1: 핸드폰이요?
# P2: 응
#
# P1: 오빠
# P2: 싼요네?
#
# P1: 네. 오빠 영화는 많이 보세요?
# P2: 영화?
#
# P1: 네.
# P2: 영화는. 주로 그~ 극장 갈 시간이 없으니까.
#
# P1: 네. 따운 받아서요?
# P2: 어 그래. 따운 받아서 주로 보지.
#
# P1: 요새는 뭐가 재밌어요? 요새 영화 안 본 지 오래 돼서.
# P2: 얼마 전에. 헬보이라고 아나. 헬보이?
#
# P1: 헬보이요?
# P2: 어.
#
# P1: 네.
# P2: 그거 재밌더라.
#
# P1: 어 그거 지금 개봉하고 있는 거 아니에요? 헬보이?
# P2: 아직.
#
# P1: 아직 개봉 안 했나?
# P2: 아직 안 했어.
#
# P1: 어
# P2: 본 슈프리머시 꼭 보고 싶어.
#
# P1: 아
# P2: 본 슈프리머시.
#
# P1: 그러면은 그런 거 따운 받고 이러는데 오래 걸리지 않아요?
# P2: 오래 걸리지.
#
# P1: 오래 얼마나요?
# P2: 어. 한 두 시간?
#
# P1:
# P2: 근데 그게
#
# P1: 네.
# P2: 한 편이 워낙. 두 시간 요즘엔 두 시간짜리 영화가 많아 가지고
#
# P1: 네.
# P2: 씨디를 세 개로 나눠
#
# P1: 네.
# P2: 어. 화질 좋은 거는
#
# P1: 네.
# P2: 화질이 좋으면 좋을수록?
#
# P1: 네.
# P2: 씨디가 늘어나.
#
# P1: 네.
# P2: 그게 또. 피투피라고. 이케 공유 화일 같은 거 해 가지고.
#
# P1: 예.
# P2: 내 컴퓨터에 있는 거를? 너한테 너가 따운 받아서 볼 수도 있고 그래
#
# P1: 아
# P2: 그거 깔면은. 좋아. 그래 가지구 하면은. 한 편 보고 있으면은. 또 받아지고. 계속 받아져
#
# P1: 아 그렇구나
# P2: 어.
#
# P1: 아 그러면은요 씨디 세 개가 필요하면
# P2: 어.
#
# P1: 다 씨디 하나가 다 차면은 다 찼으니까. 다른 거 넣으라고늫라고 나와요?
# P2: 아 씨디가 아니고? 하드에 저장하는 거야.
#
# P1: 아 하드에
# P2: 응.
#
# P1:  그면은 하드 되게 많이 차지하겠네요?
# P2: 어. 그렇지. 다 하면은 한 이 기가 정 이 메가. 아 이 이기가 정도.
#
# P1:  그러면 빨리 지우고 지우고 해야겠네요?
# P2: 그치.
#
# P1: 하나 보고 지우고 하나 보고 지우고?
# P2: 근데 영화 같은 거는 한 번 보고 나면은. 또 보고 싶어지지 않으니까
#
# P1: 음.
# P2: 지워 버리는 게 나아. 진짜 갖고 싶은 거 영화는. 디비디로 소장하면 되지. 아니면 씨디로 구워 갖고 갖고 있던지.
#
# P1: 그거 헬보이는 재밌어요?
# P2: 어.  구워꿔 줄까?
#
# P1: 아니 근데 그거 무서운 거죠?
# P2: 무서운 거 별로 없어. 거의 없어. 무서운 거는 액션의 일부이기 때문에. 칼 쓰고 막 이런 거야.
#
# P1: 아 그게 무슨 내용이에요?
# P2: 아직. 다 안 봤는데?
#
# P1: 다 안 봤어요?
# P2: 씨디가 세 장짜린데 두 장 밖에 못 봤거든?
#
# P1: 아.
# P2: 집에 가서 봐야지.
#
# P1: 또 뭐 재밌어요?
# P2: 그리고.  본 슈프리머시 그거는 꼭 봐라 남자 친구랑.
#
# P1: 그 그거 재밌어요?
# P2: 어.
#
# P1: 어 그게 어 그~ 그 사람 나오는 거 아닌가?
# P2: 맷데이먼
#
# P1: 멧 멧 맷데이먼. 멧돼지 네임.
# P1:
#
# P2: 멧돼지 네임 맷데이먼 나오는데
# P1: 네.
#
# P2: 하버드. 우등생이잖아
# P1: 맷데이먼이요?
#
# P2: 어.
# P1: 아 거기 안에서?
#
# P2: 아니 아니. 원래.
# P1: 원래?  정말요? 오
#
# P2: 그래서. 그 사람이 고백한 게. 토크쇼에 나와서 그 때 고백하는데 내가 본 건 아니야
# P1: 네.
#
# P2: 본 건 아닌데 그냥 들은 얘긴데. 썬그라스 안 끼고. 거리를 활보해도 아무도 알아보는 사람이 없대.
# P1: 왜요?
#
# P2: 그만큼 평범하게 생겼어.
# P1: 아
#
# P2: 맷데이먼.
# P1: 왜 멋있 멋있는 거 같은데
#
# P2: 그지?
# P1: 예 멋있는데  서양 사람들은 다 그런가?
#
# P2: 서양 사람들은 걔보다 멋있는 사람들 훨씬 많지
# P1: 음.
#
# P2: 잘 생겼어 맷데이먼. 근까 하 하버드 그냥 뭐~ 그냥 학생도 아니고 우등생이래잖어.
# P1: 우와.
#
# P2: 졸업했나? 우등 졸업. 멋있지?
# P1: 네.
#
# P2: 본 슈프리머시. 그게 본 아이덴티티 일 편이. 이 년 전에 나왔었거든. 그게 투야.
# P1: 본 아이덴티티요?  안 본 거 같애요.  음 아 근데 그건 뭐~ 심리 게임이라고 막 그런 거라 그러던데? 아닌가?
#
# P2: 그냥 때려 부수고 그러는 게 아니고.
# P1: 어.
#
# P2: 그~ 본이야 걔이름이.
# P1: 아.
#
# P2: 그냥 본.
# P1: 본 아이텐티티
#
# P2: 응. 본의 정체성이 일 탄이야. 한 마디로.
# P1: 음.
#
# P2: 이 사람이. 씨아이에이의 아주 최고 정예 요원인데. 기억 상실증에 걸려.
# P1: 아
#
# P2: 근데 인제 그 씨아이 그~ 그 쪽 본부에서는. 걔를 죽일라고 그러지. 워낙 뛰어나고. 또 많이 알고 있으니깐.
# P1: 어? 기억상실증이라면서요?
#
# P2: 근데 인제 뭐라 그래야 되나 아 왜 그러지?
#
#
# P2: 기억 상실증에 걸리나? 아무튼 그래 가지구. 작전 수행 중에 기억 상실에 걸려
# P1: 예.
#
# P2: 자기 혼자 정체성을 막~ 위기를 겪어
# P1: 예
#
# P2: 내가 여기 왜 있나 자기 소지품 보니까. 여권이 막~ 서로 다른 이름으로 된 게 막 일곱 장이나 있으니까.
# P1: 서로 다른 이름?
#
# P2: 어.
# P1: 아
#
# P2: 전부 다 뭐~ 브라질 여권. 미국 여권. 캐나다 여권. 전부 다 다른 이름으로 자기 얼굴을 내
# P1: 아
#
# P2: 변장이 돼 있는 거야. 위장이 돼 있는 거야.
# P1: 아.
#
# P2: 그러면서 막~ 혼란을 느껴.
# P1: 아.
#
# P2: 그런 와중에서는 이제. 씨아에이에서는 이제. 작전 수행 중에. 이케 정신을 잃어 버렸으니까.
# P1: 예.
#
# P2: 얘를 인제 없앨라 그래. 기밀이 누출이 될까 봐
# P1: 네.
#
# P2: 그래 가지구 인제 그거 거기서 걔는 빠져 나오고. 다시 복수하는 거지.
# P1: 누가?
#
# P2: 씨아이에이한테.
# P1:  본 본이 씨아이에이한테?
#
# P2: 응. 얘들한테.
# P1: 아
#
# P2: 되게 통쾌하더라.
# P1: 그래서 복수해요?
#
# P2: 일 탄에서는 이제 복수하고. 평화로운 데서 살어.
# P1: 예.
#
# P2: 일 탄 안 보면 이 탄도 아마. 재미없을 거야.
# P1: 아 정말요?
#
# P2: 어.
# P1: 어 일 탄 안 봤는데.
#
# P2: 아 그면은
# P1: 네.
#
# P2: 뭐~. 남자 친구한테 뭐~ 씨디로 꾸어' 달라 그래.
# P1: 어 그래야겠다.
#
# P2: 받아 가지고. 그건 진짜 재밌어. 명화야 명화.
# P1: 아.
#
# P2: 되게 막~ 흥미진진하고.
# P1: 봐야겠다.
#
# P2: 이 탄부 이 탄은 일 탄 끝난 데서부터 시작해. 끝나는 데부터.
# P1:  아 정말요? 이~ 연 연 연결된 거예요?
#
# P2: 어. 완결편처럼 끝난 건줄 알았는데. 보니까 내용이 연관이 있어.
# P1: 아 그럼 그거 보고 봐야겠다
#
# P2: 그치.  이제 어디 가니?
# P1: 네?
#
# P2: 인제 어디 가냐?
# P1: 어디요?
#
# P2: 뭐~ 너 다 끝나고 어디 가.
# P1: 아 오빠 오빠랑
#
# P2: 응.
# P1: 오빠랑 저기 하면요?
#
# P2: 응.
# P1: 과외요. 과외.
#
# P2: 과외 어디서 하는데?
# P1: 과외 동네에서요.
#
# P2: 동네에서 해
# P1: 네.
#
# P2: 뭐 뭐 가르쳐?
# P1: 네?
#
# P2: 뭐 뭐 가르쳐?
# P1: 영어요.
#
# P2: 영어?
# P1: 네.
#
# P2: 아 지혜 영어도 잘하겠다.
# P1: 아니에요. 못해요.
#
# P2: 영어면은. 저기 뭐냐. 몇 학년인데?
# P1: 고삼이요.
#
# P2:  고삼?
# P1: 네.
#
# P2: 힘들지?
# P1: 아니 별로 별로 안 힘들어요.
#
# P2: 힘들진 않어?
# P1: 네. 대화 중간에 팥빙수를 만들기 위해 얼음 가는 소리가 계속 들림. 아 이거
#
# P2: 너무 시끄러워 가지구 녹음이 좀 되나?
# P1: 아 그러게. 빙수 가는 소린가 시끄러워서. 한 번 들어 봐 정지 시키고.
#
# P1: 잘 되는 거 같애요. 괜찮아요.
# P2: 그래?
#
# P1: 네.
# P2: 아니 이거
#
# P1: 네.
# P2: 한 번 해 봐.
#
# P1:  잘 들려요.
# P2: 이거는 왜 여기다 찼어?
#
# P1: 아 이거요? 이거 자꾸만 여기 뭐가 나서
# P2: 음.
#
# P1: 세 세수하거나 이럴 때는. 뺐다가 하고 해야 하는데. 그냥 끼고 해서.
# P1: 어디 있다 오시는 거예요?
#
# P2: 나?
# P1: 예.
#
# P2: 아. 저기 뭐~ 뭐 좀 좀 사러 갔다가.
# P1: 아.
#
# P2: 백화점 앞에 있는.
# P1: 아.
#
# P2: 옷가지 좀 샀어.
# P1: 옷이요?
#
# P2: 응.
# P1: 저게 산거예요?
#
# P2: 응.
# P1: 아. 오빠?
#
# P2:  내가 좀 옷 욕심이 좀 많아 가지고.
# P1: 아. 오빠는 무슨 옷? 어떤 옷 종류. 입 입으세요?
#
# P2: 아. 옷? 편한 거 진짜.
# P1: 캐주얼이요?
#
# P2: 응.
# P1: 음. 그래도 이젠 나이가 있는데.
#
# P2: 나이?
# P1: 예
#
# P2: 너도 이제 금방이다 이 놈아.
# P1:
#
# P2: 진짜야 나도 진짜 안 올 줄 알았어.
# P1:
#
# P2: 금방 와 진짜. 그니까 준비를 해야 돼
# P1: 무슨 준비요?
#
# P2: 뭐~ 노후 대책이라든지.
# P1:
#
# P2: 이런 건 아니더라도
# P1: 네.
#
# P2: 준빌 해야지
# P1:
#
# P2: 돈 좀 모아 놓고.
# P1: 응
#
# P2: 쓸 데는 쓰는 게 돈이지만은 미래를 위해서. 생각 있으면 돈 좀 모아 놓고 그래라.
# P1: 응.
#
# P2: 잘 안 모아지더라고.
# P1: 가을 옷 사신 거예요?
#
# P2: 가을 옷?
# P1: 네.
#
# P2: 그냥 긴팔
# P1: 긴팔?
#
# P2: 얇은 거.
# P1: 요샌 쎄일 안 하죠?
#
# P2: 요즘에 하는 데 있어.
# P1: 있어요?
#
# P2: 신상품 당연히 쎄일 안 하고.
# P1: 어.
#
# P2: 이젠 반팔이 들어갈 때가 되니까.
# P1: 아.
#
# P2: 겨울엔 반팔 팔겠지.
# P1: 아.  어디 안 갔다 오셨어요 휴가?
#
# P2: 아 친구들하고. 거기 갔다 왔어.
# P1: 어디요?
#
# P2: 설악산 이 쪽에.
# P1: 설악산이요? 어
#
# P2: 음.
# P1: 오빠네 휴가는 한 며칠인데요?
#
# P2: 우리 오 일.
# P1: 오 일?
#
# P2: 응.
# P1: 어 그래도 꽤 많네요?
#
# P2: 꽤 길지.
# P1:  꽤 기네요.
#
# P2: 아.
# P1: 음 설악산 어디 갔다 오셨는데요?
#
# P2: 아 친구가 거기  산에?
# P1: 아니요
#
# P2: 아. 설악산에?
# P1: 뭐~ 일박 이일이요?
#
# P2: 아니 이박 삼일로 갔지. 친구가. 그 쪽에 콘도가 있어
# P1: 아 차 가지고요?
#
# P2: 어. 차 가지고.
# P1: 아
#
# P2: 오빠 차랑. 오빠 차 오빠 차랑 해 가지고.
# P1: 네.
#
# P2: 친구 차랑 해 가지구.
# P1: 아 두 대로 갔어요?
#
# P2: 두 대로 갔어.
# P1: 음.
#
# P2: 어. 친구들? 오랜만에 만나 가지구. 대학 친구들 모아 가지구.
# P1: 음
#
# P2: 일곱 명에서 갔다 왔지.
# P1: 어 그래도 그렇게 만나지네요? 아 졸업하고 이래도?
#
# P2: 그치?
# P1: 음
#
# P2: 응. 애들이 좀 끈끈해
# P1: 음.
#
# P2: 그래 가지고  설악산 가서.
# P1: 네.
#
# P2: 친구가 콘도가 있거든?
# P1: 네.
#
# P2: 콘도가. 두 개가 있어
# P1: 네. 콘도가 두 개가 있어요? 네.
#
# P2: 같은 같은. 타이틀이 같은 콘돈데.
# P1: 응. 응.
#
# P2: 얘가 지점이 두 개가 있는 거야. 설악산 쪽에 하나 있고. 저기 동해안 쪽에 하나 있어.
# P1: 아
#
# P2: 하루는. 첫날은 설악산 쪽 가 가지구 놀고?
# P1: 네.
#
# P2: 그 다음에 둘째 날은 인제 비치.
# P1: 아
#
# P2: 걸루 가 가지구 놀구? 올라오면서.
# P1: 응.
#
# P2: 래프팅 타고 놀았지.
# P1: 어디 동강이요?
#
# P2: 아니 인제. 강원도 인제 가면은
# P1: 아 강원도? 아 하긴 그게 다 강원도에 있었으니깐.
#
# P2: 그치 좋아. 동강인가? 동강 가깝나? 잘 모르겠다.
# P1: 아 인제?
#
# P2:  사람들 많이 오더라
# P1: 음
#
# P2: 별로 위험하지도 않고 나중에 한 번 남자 친구랑 가 봐
# P1: 아 저도. 래프팅 할라 이번에 하고 싶었는데
#
# P2: 응.
# P1: 별로 애들이 호응이 없어서.
#
# P2: 너 어디 갔는데?
# P1: 저요? 저 친구들이랑 여행 갔다 왔어요. 위도.
#
# P2: 위도?
# P1: 네. 위도 아세요?
#
# P2: 저기 춘천에 있는 위도 아냐?
# P1:  아니요. 춘천에 있는 거는.  중도.
#
# P2: 아
# P1: 그리고. 제주도에 우도.
#
# P2: 아 우도? 우도는 유명하지.
# P1: 그러고 경남에. 경남 쪽에. 경남인가?
#
# P2: 어.
# P1: 아닌데. 맨 아무튼 끝에 외도. 외도라고 있어요. 외도. 그런데 저희는 위도예요.
#
# P2: 위도?
# P1: 네. 남해안 쪽에 외도 있는데. 저희는 위도.
#
# P2: 위도가 어딘지 몰라.
# P1: 위도는요? 되게 복잡해요. 여기서 부안까지
#
# P2: 아 부안 거기
# P1: 예. 핵 뭐~ 폐기장.
#
# P2: 아.
# P1: 부안까지. 고속버스 타고 가서요?
#
# P2: 응.
# P1: 거기서 격포항까지
#
# P2: 응.
# P1: 한 다시 또 시내버스 타서. 또 격포항에서 한 위도까지 배타고 한 사십 분 타고 들어갔죠?
#
# P2: 고생이다.
# P1: 되게 좋아요 그래서 탔잖아요.
#
# P2: 그러게. 너 하얬는데.
# P1: 네. 되게 새까매졌죠?
#
# P2: 응.  아 우리가 들어오니까 사람이 많이 들어오네.
# P1:  그러게요.
#
# P2: 이런 데 자주 오니?
# P1: 저요? 여기 싸니까
#
# P2: 싸? 여기가 젤 싸?
# P1: 여기가 젤 싸요. 자판기 커피 다음으로.
#
# P2: 어 그래? 천구백 원이 젤 싸?
# P1: 그럼요
#
# P2: 여기서 과외 하는 덴 가까워?
# P1: 여기서 예 여기서 가까워요.
#
# P2: 음.
# P1: 인제 어디 가세요? 집으로 가세요?
#
# P2: 나?
# P1: 네.
#
# P2: 집으로 가서 좀 올림픽이나 봐야지.
# P1: 아 올림픽?
#
# P2: 어.  아 이 노래 나오네.  이 노래가 언제 나온 노래지?
# P1: 이 노래 이 노래가 뭐죠?  지 지오디 노랜가요?
#
# P2: 가드야 가던
# P1: 맞아요? 맞아요? 아
#
# P2: 지혜는 뭐~ 유학 같은 거 가고 싶지 가고 싶지 않아?
# P1: 유학이요?
#
# P2: 응. 저는 외국에 가서. 외국에까지 가서 공부하고 싶은 생각은 별로 없고요
# P2: 응
#
# P1: 그냥 놀러는 가고 싶어요.
# P2: 아.
#
# P1: 짧게.
# P2: 짧게?
#
# P1: 한 육 개월 마~ 이렇게
# P2: 그게 짧어?
#
# P1: 그냥 뭐~ 여행이나.
# P2: 아
#
# P1: 연수 같은 거 잠깐.
# P2: 여행 좋지.
#
# P1: 유학은 싫어요.
# P2: 음. 돈이 많이 들지.
#
# P1: 아 저번에  학원 저 학원 다니거든요? 영어 토익학원?
# P2: 응.
#
# P1: 근데 거기서 있는데 어떤 애들끼리 얘길 하는 거예요. 유학 애길 하는 거예요. 근데? 뭐~ 유학원 이런 델 갔다 왔는지. 뭐~ 자료 이만큼씩 가지구서 막~ 얘기하는데? 뭐~ 너네 학교는 뭐~ 육 개월에 뭐~ 천오백만 원 아 삼 개월에 천오백만 원이랬나? 아 육 개월에. 막~ 그러면서 막~ 그런 식으로 얘기하던데요.
# P2: 비싸다.
#
# P1: 예 아마 아 육 개월에 천오백만 원이랬나?
# P2: 천오백이면 요즘 등록금이 얼마지?
#
# P1: 요새. 저흰 이백칠십?
# P2: 이백칠십? 한 삼백 치면은 오 학기는 다닐 수 있네?
#
# P1:  진짜. 어 웬일이야 한 달 한 달에 등록금값이네요?
# P2: 그러니까
#
# P1: 어우 비싸구나. 천오백만 원이래서 별로 그렇게 별로 감이 안 왔는데. 그렇게 그렇게 생각하니깐. 되게 비싸네요?
# P2: 그렇지. 등록금으로 생각하면은.
#
# P1: 음.
# P2: 감당하기 힘들지.
#
# P1: 음. 오빠 친구 중에는. 뭐~ 유학 간 사람 없어요?
# P2: 유학?
#
# P1: 네.
# P2: 다 뭐~. 없지 뭐~.  대학원 대학원 간 친구는. 대학원 반. 취직 반.
#
# P1: 대학원도 많이 가요?
# P2: 많이 가지.
#
# P1: 음 왜요? 뭐~ 취직이 안 돼서?
# P2: 그런 거보다도. 그냥 좀. 공부 더하고 싶은 친구들이. 있더라고.
#
# P1: 음.
# P2: 살다 보니까.
#
# P1: 어 난 되게 싫던데.
# P2: 뭐~ 걔네들도 좋아서 하겠냐. 다 그냥. 필요할 것 같으니까 하는 거지. 왜 하는지도 모르는 사람들도 많을 걸?
#
# P1: 대학원까지 갔는데?
# P2: 어.  그냥 가방 끈. 늘리는 거지.
#
# P1:  길게
# P2: 아무래도. 공부 많이 하면은. 대접 받으니까.
#
# P1: 아
# P2: 우리 나라는. 전통적으로.
#
# P1: 맞아요.
# P2: 문관들을 대우해 주잖아. 무관보다.
#
# P1: 맞아요.
# P2: 근까 뭐~ 유학 갔다 온 사람 더. 좋아하고
#
# P1: 어.
# P2: 아무래도 가방 끈 쫌이라도 더 긴 사람들 우대해 주고. 우리 회사에서도 많은데. 대학원. 출신이 많은데
#
# P1: 대학원출신이요?
# P2: 어.
#
# P1: 예.
# P2: 그게 쫌. 우리 회사가 특성이 이제. 자동차 회사다 보니까.
#
# P1: 네.
# P2: 뭐~ 물론 전문 인력이 많이 필요하지.
#
# P1: 네.
# P2: 자동차라는 거 자체가
#
# P1: 네.
# P2: 솔직히 공고. 출신들이 더 많이 알 수 있거든? 자동차는?
#
# P1: 자동차에 대해서. 아
# P2: 뭐~ 뭐가 문제 있나. 뭐~ 어딘 어띃게. 설계를 해야 된다.
#
# P1: 네.
# P2: 솔직히 공학적인 그런. 지식이 절대적으로 필요한 거는. 그렇게 많지가 않어.
#
# P1: 네.
# P2: 현장서 배우는 거지. 그러다 보니까 석사 출신들이? 단지 그냥 학사보다는. 이 년 더 경력을 인정 받는 거 밖에 없어.
#
# P1: 아니 대학원 나오면은. 취직이 더 잘 돼요? 그런 건 아니죠.
# P2: 꼭 그런 건 아냐. 응.
#
# P1: 그래두
# P2: 티오가 있지. 어딜 가나.
#
# P1: 음
# P2: 대학원 몇 명. 학사 몇 명.
#
# P1: 하긴 아예 뭐~ 요강이 틀리니깐
# P2: 요강
#
# P1: 취직 취직할 때.
# P2: 아.
#
# P1: 그 아예 틀리잖아요. 그 자격이.
# P2: 그치.  어디 전공이 중요하지.  박사 출신이면은 아무래도 자기가 연구한 분야 같은 거고.  다 여자들이네.
#
# P1:  원래 커피숍 오면 다 여자예요.  어 꽉 찼네요.
# P2: 그러니까.
#
# P1: 몰랐는데. 이럴 때 만땅이라고 하지.
# P1:   어 이제 개강이 얼마 안 남았어요. 아! 개강이 얼마 안 남았어요.
#
# P2: 편하게 해
# P1: 저도 이제 칠 학기잖아요.
#
# P2: 어.
# P1: 학점도 잘 받아야 되는데. 클났네.
#
# P2: 이런 말이 실례일진 모르겠지만 학점은 잘 나왔어?
# P1: 예?
#
# P2: 학점은 좋아?
# P1: 학점이요?
#
# P2: 너네가. 서강대면. 사점 삼 만점이지?
# P1: 예. 별로 안 좋아요.
#
# P2: 삼 점은 넘을 거 아냐?
# P1: 헤헤 삼 점은 넘죠.
#
# P2: 어우 진짜?
# P1: 네.
#
# P2: 의왼데?
# P1:
#
# P2: 몇 점 이상 맞아야 된대?
# P1: 뭐~ 저~ 삼성화재 들어간 오빠는요 삼 점 육? 삼 점 육이랬나. 삼 점. 육이랬나 삼 점 칠이랬나.
#
# P2: 삼성화재면 면접을 잘 봐야 될걸?
# P1: 면접? 아.
#
# P2:  응.
# P1: 그러게요.
#
# P2: 그리구 삼성은 서울대 진짜 안 뽑는대더라.
# P1: 어? 왜요?
#
# P2: 안 뽑는데.
# P1: 서울대를요?
#
# P2:  주변에 서울대가 별로 없대. 오히려 지방대. 지방대면은. 국립대 정도?
# P1: 아
#
# P2:  뭐~ 고 다음에 서강대. 연대. 뭐~ 고대. 고 그룹에서 뽑나 봐. 서울대 위주로 아니구.
# P1: 아
#
# P2: 그리구 삼성은. 기독교 많이 안 뽑잖아.
# P1: 어 정말요?
#
# P2: 응.
# P1: 그런 것도 봐요?
#
# P2: 응.
# P1: 어 난 천주굔데.
#
# P2: 그럼 유리하겠네.
# P1: 왜요?
#
# P2: 기독교랑 천주교는. 확실히 다르지.
# P1: 음
#
# P2: 어우 계속 졸리다 야.
# P1: 예. 날씨가 그래서 피곤한가?
#
# P2: 날씨가. 비 와서?
# P1: 날씨가 좀 어째 좀 그렇잖아요? 사람을 좀. 지치게 하고.
#
# P2: 집에 가는 길에 꼐속 자면서 가야겠다.
# P1: 여기서 집에까지 얼마나 걸리세요?
#
# P2:  지하철로만. 삼십 분?
# P1: 삼십 분?
#
# P2: 어. 갈아타는 것까지 다 감안하면.
# P1: 아. 금방? 가네요?
#
# P2: 응.  출출하지 않냐?
# P1: 출출하세요? 오빠 저녁 안 드셨어요?
#
# P2: 먹었어. 오빠는.
# P1:  아. 뭐 드셨는데요?
#
# P2: 뭐~ 볶음밥 같은 건데.
# P1: 네.
#
# P2: 먹을 만하더라.
# P1: 아.
#
# P2: 편의점에서 컵라면 하나 먹고 갈까?
# P1: 컵라면이요?
#
# P2: 응. 근처에 편의점 있니?
# P1: 편의점. 있 있을래요.
#
# P2: 있을래요?
# P1: 있어요.
#
# P2: 있을래요?
# P1:   오늘 수요일. 아우. 아 또 밤에 과외 갈 생각하니까 또. 귀찮고.
#
# P2: 아 옛날에 과외 많이 했을 때는 진짜
# P1: 네.
#
# P2: 돈 줄 때만 좋았지 씨.
# P1: 과외. 돈 줄 때만요?
#
# P2: 어.  어디서 계피 냄새
# P1: 예? 계피 냄새?
#
# P2: 재채기하면 이런 냄새 나.
# P1: 몰라요.
#
# P2: 재채기하면 이런 냄새나는 거 모르나?
# P1: 몰르겠어요.
#
# P2: 계피 냄새  아이쿠. 와. 녹음기 얼마야?
# P1: 아 이거는 거기서 준 준 거예요. 아니 준 게 아니라. 영 이거 녹음하라구. 빌려 준 거예요.
#
# P2: 아 아. 아 라이트 라이트. 레프트 레프트. 아 아 아. 왼쪽 왼쪽.
# P1:
#
# P2: 양쪽으로 해야지 그지?
# P1: 네. 녹음 잘 오빠 목소리가 녹음이 잘 됐나 모르겠네.
#
# P2: 왜?
# P1: 몰라. 여기서 들으니깐 잘 멀 먼 거 먼 거 같기두 하구.
#
# P2: 아 그래?
# P1: 네.
#
# P2: 아 그럼 안 되는데. 한 번 확인해 봐
# P1: 예. 있다가. 한 번 확인해 봐야겠다. 오빠 이제 지금 집에 가셔야죠?
#
# P2: 그래. 컵라면 하나 먹고 가야겠다.
# P1: 아 네. 그면은? 이거를? 이제 꺼야겠다.
#
# P2: 응.
# P1: 오빠 고맙습니다.
#
# P2: 아 별말씀을.
# P1:
